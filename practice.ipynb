# %% [markdown]
# <a href="https://colab.research.google.com/github/hsunlim72/Ilsan_AI_education/blob/HyunsunLim/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

# %%
# Google drive에서 자료 가져오기
from google.colab import drive  # for colab
drive.mount('/content/gdrive/')  # for colab
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
cloud_directory = '/content/gdrive/MyDrive/sample/'
os.listdir(cloud_directory) # for colab, check cloud directory mount
# Out:
# ['nhid_gy20_t1.csv',
#  'nhid_gy30_t1.csv',
#  'nhid_gy60_t1.csv',
#  'nhid_jk.csv',
#  'id.csv',
#  'nhid_gj.csv']

# %%
ID = pd.read_csv('{}/id.csv'.format(cloud_directory),keep_default_na = False, encoding='cp949')
ID
# Out:
#        PERSON_ID  sampling
# 0       11416684         1
# 1       11435193         1
# 2       12282221         1
# 3       12582450         1
# 4       12645281         1
# ...          ...       ...
# 99995   94418802         1
# 99996   94420539         1
# 99997   94424639         1
# 99998   94424892         1
# 99999   94428424         1
#
# [100000 rows x 2 columns]

# %%
T20 = pd.read_csv('{}/nhid_gy20_t1.csv'.format(cloud_directory),keep_default_na = False, encoding='cp949')
T20
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (5,9,13,15,16,17,18,19,20,21,22,23,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           PERSON_ID       KEY_SEQ  YKIHO_ID  RECU_FR_DT  FORM_CD DSBJT_CD  \
# 0          55455550  200206164032         1    20020606        3        1
# 1          70533868  200208415526         1    20020917        3        1
# 2          36873593  200208415377         1    20020926        3        4
# 3          70533868  200209411045         1    20021022        3        1
# 4          47026415  200211447142         1    20021205        3       12
# ...             ...           ...       ...         ...      ...      ...
# 10517397   22299333  201303096421    183943    20131224        3        1
# 10517398   22299333  201303096420    183943    20131221        3        1
# ...

# %%
T30 = pd.read_csv('{}/nhid_gy30_t1.csv'.format(cloud_directory),keep_default_na = False, encoding='cp949')
T30
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-9-23e77b4ecb17> in <module>
# ----> 1 T30 = pd.read_csv('{}/nhid_gy30_t1.csv'.format(cloud_directory),keep_default_na = False, encoding='cp949')
#       2 T30
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
T60 = pd.read_csv('{}/nhid_gy60_t1.csv'.format(cloud_directory),keep_default_na = False, encoding='cp949')
T60
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (3,4,7,9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                KEY_SEQ  SEQ_NO  RECU_FR_DT DIV_TYPE_CD     DIV_CD  GNL_NM_CD  \
# 0         200200000108       1    20021227           3  A03002461  113101ATB
# 1         200200000108       2    20021227           3  A35150611  101804ACH
# 2         200200000108       3    20021227           3  A19201701  259700ATB
# 3         200200000108       4    20021227           3  A08601941  254400ACH
# 4         200200000108       5    20021227           3  A04850711  113304ATB
# ...                ...     ...         ...         ...        ...        ...
# 33744617  201328016532       2    20131230           3  643101920  161201COS
# 33744618  201328016532       1    20131230           3  643703520  183204COS
# ...

# %%
JK = pd.read_csv('{}/nhid_jk.csv'.format(cloud_directory),keep_default_na = False, encoding='cp949')
JK
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          SEX  AGE_GROUP  STND_Y  PERSON_ID DTH_YM DTH_CODE1 DTH_CODE2  SIDO  \
# 0          1          0    2002   11416684                               41
# 1          1          0    2002   11435193                               48
# 2          1          0    2002   12282221                               26
# 3          1          0    2002   12582450                               46
# 4          1          0    2002   12645281                               46
# ...      ...        ...     ...        ...    ...       ...       ...   ...
# 1126547    1         12    2013   96076800                               44
# 1126548    2         17    2013   96217540                               11
# ...

# %%
GJ = pd.read_csv('{}/nhid_gj.csv'.format(cloud_directory),keep_default_na = False, encoding='cp949')
GJ
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (5,6,7,8,9,14,15,16,35,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         HCHK_YEAR  PERSON_ID  YKIHO_GUBUN_CD HEIGHT WEIGHT BP_HIGH BP_LWST  \
# 0            2002   10069041              31    161     70     190     110
# 1            2002   10116196              31    167     58     120      70
# 2            2002   10201078              20    164     67     160     100
# 3            2002   10207530              30    168     74     160     110
# 4            2002   10213680              10    165     66     140      80
# ...           ...        ...             ...    ...    ...     ...     ...
# 215664       2013   75661173              10    165     62     106      64
# 215665       2013   74119869              35    158     44      97      58
# ...
